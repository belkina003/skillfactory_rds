# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("../input"))
# Out:
# ['.ipynb_checkpoints', 'data.csv', '[SF-DST] Movies IMBD v3.0.ipynb']

# %%
data = pd.read_csv('../input/data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data[data.budget==data.budget.max()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year
# 491    12/2/2010          74           6.4          2010

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data.sort_values(by='runtime',ascending=False).head(1)
# Out:
#         imdb_id  popularity    budget   revenue     original_title  \
# 1158  tt0279111    0.469518  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1158  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1158  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1158  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_count  vote_average  release_year
# 1158          23           5.8          2003

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data.sort_values(by='runtime').head(1)
# Out:
#        imdb_id  popularity    budget   revenue   original_title  \
# 769  tt1449283    1.425344  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 769  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 769  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 769  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 769  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_count  vote_average  release_year
# 769    4/13/2011         174           6.8          2011

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data.runtime.mean()
# Out:
# 109.65343915343915

# %%
answer_ls.append(2)

# %%
data.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  1890.000000  1.890000e+03  1.890000e+03  1890.000000  1890.000000
# mean      1.560611  5.450696e+07  1.552890e+08   109.653439   785.666667
# std       1.849471  4.931705e+07  2.146386e+08    18.013641  1068.725880
# min       0.010335  5.000000e+06  2.033165e+06    63.000000    10.000000
# 25%       0.643284  2.000000e+07  3.434007e+07    97.000000   164.000000
# 50%       1.065065  3.800000e+07  8.358664e+07   106.500000   389.000000
# 75%       1.804537  7.200000e+07  1.782136e+08   120.000000   937.750000
# max      32.985763  4.250000e+08  2.781506e+09   214.000000  9767.000000
#
#        vote_average  release_year
# count   1890.000000   1890.000000
# mean       6.140899   2007.861905
# std        0.764584      4.467929
# min        3.300000   2000.000000
# 25%        5.600000   2004.000000
# 50%        6.100000   2008.000000
# 75%        6.600000   2012.000000
# ...

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.runtime.median()
# Out:
# 106.5

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit']=data['revenue']-data['budget']
data.sort_values(by='profit',ascending=False).head(1)
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year      profit
# 239        8458           7.1          2009  2544505847

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data.sort_values(by='profit').head(1)
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     profit
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data[data.profit>0].imdb_id.count()
# Out:
# 1478

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data[data.release_year==2008].sort_values(by='profit',ascending=False).head(1)
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year     profit
# 600        8432           8.1          2008  816921825

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data[data.release_year.isin([2012,2013,2014])].sort_values(by='profit').head(1)
# Out:
#         imdb_id  popularity     budget   revenue   original_title  \
# 1246  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1246  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1246  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1246  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1246  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_count  vote_average  release_year     profit
# 1246        1607           6.0          2013 -165710090

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
s=['Action', 'Adventure','Drama','Comedy','Thriller']
for i in s:
    x=data.genres.str.contains(i).sum()
    print(i,':',x)
# Out:
# Action : 583
# Adventure : 416
# Drama : 782
# Comedy : 683
# Thriller : 597

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
s=['Action', 'Adventure','Drama','Comedy','Thriller']
for i in s:
    x=data[data['profit']>0].genres.str.contains(i).sum()
    print(i,':',x)
# Out:
# Action : 444
# Adventure : 337
# Drama : 560
# Comedy : 551
# Thriller : 446

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data.director.value_counts()
# Out:
# Steven Soderbergh                   13
# Clint Eastwood                      12
# Ridley Scott                        12
# Steven Spielberg                    10
# Shawn Levy                          10
#                                     ..
# William Dear                         1
# Chris Renaud|Kyle Balda              1
# Mabrouk El Mechri                    1
# Jonathan Dayton|Valerie Faris        1
# Florian Henckel von Donnersmarck     1
# Name: director, Length: 958, dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
data[data.profit>0].director.value_counts()
# Out:
# Ridley Scott                        12
# Steven Spielberg                    10
# Steven Soderbergh                   10
# Clint Eastwood                      10
# Shawn Levy                           9
#                                     ..
# Juan Antonio Bayona                  1
# Greg Coolidge                        1
# Drew Goddard                         1
# Kevin Allen                          1
# Florian Henckel von Donnersmarck     1
# Name: director, Length: 774, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
data[data.director.isin(['Steven Spielberg','Christopher Nolan','David Yates','James Cameron','Peter Jackson'])].groupby(['director'])['profit'].agg('sum')
# Out:
# director
# Christopher Nolan    3162548502
# David Yates          3379295625
# James Cameron        2548546718
# Peter Jackson        5202593685
# Steven Spielberg     2449700791
# Name: profit, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
cast1=['Emma Watson', 'Johnny Depp','Michelle Rodriguez','Orlando Bloom','Rupert Grint']
for i in cast1:
    x=data[data.cast.str.contains(i)].profit.sum()
    print(i,':',x)
# Out:
# Emma Watson : 6666245597
# Johnny Depp : 4776417000
# Michelle Rodriguez : 4608031235
# Orlando Bloom : 5148578162
# Rupert Grint : 6408638290

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
cast2=['Nicolas Cage', 'Danny Huston','Kirsten Dunst','Jim Sturgess','Sami Gayle']
for i in cast2:
    x=data[(data.cast.str.contains(i)) & (data.release_year==2012)].profit.sum()
    print(i,':',x)
# Out:
# Nicolas Cage : -32893443
# Danny Huston : -32893443
# Kirsten Dunst : -68109207
# Jim Sturgess : -23410657
# Sami Gayle : -32893443

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
cast2=['Tom Cruise', 'Mark Wahlberg','Matt Damon','Angelina Jolie','Adam Sandler']
for i in cast2:
    x=data[(data.cast.str.contains(i)) & (data.budget>data.budget.mean())].cast.count()
    print(i,':',x)
# Out:
# Tom Cruise : 15
# Mark Wahlberg : 14
# Matt Damon : 18
# Angelina Jolie : 16
# Adam Sandler : 17

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
genre1=['Drama', 'Action','Thriller','Adventure','Crime']
for i in genre1:
    x=data[(data.genres.str.contains(i)) & (data.cast.str.contains('Nicolas Cage'))].genres.count()
    print(i,':',x)
# Out:
# Drama : 12
# Action : 17
# Thriller : 15
# Adventure : 7
# Crime : 10

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
studio=['Universal', 'Paramount Pictures','Columbia Pictures','Warner Bros','Twentieth Century Fox Film Corporation']
for i in studio:
    x=data[data.production_companies.str.contains(i)].production_companies.count()
    print(i,':',x)
# Out:
# Universal : 185
# Paramount Pictures : 122
# Columbia Pictures : 163
# Warner Bros : 183
# Twentieth Century Fox Film Corporation : 109

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
studio1=['Universal Pictures', 'Paramount Pictures','Columbia Pictures','Warner Bros','Twentieth Century Fox Film Corporation']
for i in studio1:
    x=data[(data.production_companies.str.contains(i)) & (data.release_year==2015)].production_companies.count()
    print(i,':',x)
# Out:
# Universal Pictures : 11
# Paramount Pictures : 7
# Columbia Pictures : 7
# Warner Bros : 12
# Twentieth Century Fox Film Corporation : 8

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
studio2=['Warner Bros', 'Universal','Columbia Pictures','Paramount Pictures','Walt Disney']
for i in studio2:
    x=data[(data.production_companies.str.contains(i)) & (data.genres.str.contains('Comedy'))].profit.sum()
    print(i,':',x)
# Out:
# Warner Bros : 4370928916
# Universal : 9130349034
# Columbia Pictures : 7161805266
# Paramount Pictures : 3055625722
# Walt Disney : 7975933215

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
studio3=['Universal', 'Warner Bros','Columbia Pictures','Paramount Pictures','Lucasfilm']
for i in studio3:
    x=data[(data.production_companies.str.contains(i)) & (data.release_year==2012)].profit.sum()
    print(i,':',x)
# Out:
# Universal : 1981011579
# Warner Bros : 1258020056
# Columbia Pictures : 2501406608
# Paramount Pictures : 410726715
# Lucasfilm : -7634623

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
data[data.production_companies.str.contains('Paramount Pictures')].sort_values(by='profit').head(5)
# Out:
#         imdb_id  popularity     budget   revenue        original_title  \
# 926   tt0267626    0.722330  100000000  35168966  K-19: The Widowmaker
# 1124  tt0300556    1.047214   80000000  19480739              Timeline
# 1723  tt0435705    1.068126   70000000  18211013                  Next
# 1624  tt0375173    0.898601   60000000  13395939                 Alfie
# 1632  tt0315297    0.767870   50000000  25195000               Twisted
#
#                                                    cast         director  \
# 926   Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
# 1124  Paul Walker|Frances O'Connor|Gerard Butler|Bil...   Richard Donner
# 1723  Nicolas Cage|Julianne Moore|Jessica Biel|Thoma...     Lee Tamahori
# 1624  Jude Law|Marisa Tomei|Omar Epps|Jane Krakowski...    Charles Shyer
# 1632  Ashley Judd|Samuel L. Jackson|Andy GarcÃ­a|Dav...   Philip Kaufman
#
#                                                 tagline  \
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data.groupby(['release_year']).profit.sum()
# Out:
# release_year
# 2000     6101399805
# 2001     7950614865
# 2002     9002361487
# 2003     9228823312
# 2004     9634180720
# 2005     8981925558
# 2006     8691077320
# 2007    11565911801
# 2008    11663881990
# 2009    13423744372
# 2010    13117292530
# 2011    14730241341
# 2012    16077001687
# 2013    15243179791
# 2014    16397812953
# 2015    18668572378
# Name: profit, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
data[data.production_companies.str.contains('Warner Bros')].groupby(['release_year']).profit.sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
def func(s):
    sp=[]
    sp=s.split('/')
    return sp[0]
data['month']=data.release_date.apply(func)
data.month.value_counts()
# Out:
# 9     227
# 12    191
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: month, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
data[data.month.isin(['6','7','8'])].month.count()
# Out:
# 450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
direct=['Steven Soderbergh', 'Christopher Nolan','Clint Eastwood','Ridley Scott','Peter Jackson']
for i in direct:
    x=data[(data.director.str.contains(i)) & (data.month.isin(['12','1','2']))].imdb_id.count()
    print(i,':',x)
# Out:
# Steven Soderbergh : 6
# Christopher Nolan : 0
# Clint Eastwood : 6
# Ridley Scott : 3
# Peter Jackson : 7

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
pivot=data[data.month.isin(['1','6','12','9','5'])].pivot_table(values=['profit'], index=['release_year'], columns=['month'], aggfunc='sum',
                      fill_value=None, dropna=True)
pivot['max']=pivot.max(axis=1)
pivot
# Out:
#                  profit                                                  \
# month                 1          12           5           6           9
# release_year
# 2000          -26344591  1411487999  1382722190   517315528   175306761
# 2001          127876758  1703868124   767934975   780612105    21874909
# 2002           13657034  1848074177  1421928692   747704475   417267245
# 2003          145423503  1862594516  2000292657   406445507   503313816
# 2004          223449403  1106961735  2412578839  1294266591   475369751
# 2005          419099490  1354115156  1575566228  1193230558   995622427
# 2006          138996816   935240354   985092012  2098059770   451456811
# 2007           91188025  1831805203  2042169546  2764341802   435838557
# 2008          440344541  1126935570  1744305931  1943384763   339476350
# 2009          996529660  3423239738  1435747314  1520284741   393041320
# 2010          233051923   899583599  1105092975  2449561498  1091274243
# ...

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data['len_title']=data.original_title.apply(len)
data.head()
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
studio4=['Universal', 'Warner Bros','Jim Henson Company, The','Paramount Pictures','Four By Two Productions']
for i in studio4:
    x=data[data.production_companies.str.contains(i)].len_title.mean()
    print(i,':',x)
# Out:
# Universal : 14.762162162162163
# Warner Bros : 15.251366120218579
# Jim Henson Company, The : 59.0
# Paramount Pictures : 17.0327868852459
# Four By Two Productions : 83.0

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
def count_word(x):
    s=[]
    s=x.split()
    return(len(s))
data['count_words']=data.original_title.apply(count_word)
data[['original_title','count_words']].head(10)
# Out:
#                  original_title  count_words
# 0                Jurassic World            2
# 1            Mad Max: Fury Road            4
# 2                     Insurgent            1
# 3  Star Wars: The Force Awakens            5
# 4                     Furious 7            2
# 5                  The Revenant            2
# 6            Terminator Genisys            2
# 7                   The Martian            2
# 8                       Minions            1
# 9                    Inside Out            2

# %%
studio4=['Universal', 'Warner Bros','Jim Henson Company, The','Paramount Pictures','Four By Two Productions']
for i in studio4:
    x=data[data.production_companies.str.contains(i)].count_words.mean()
    print(i,':',x)
# Out:
# Universal : 2.627027027027027
# Warner Bros : 2.73224043715847
# Jim Henson Company, The : 10.0
# Paramount Pictures : 2.8688524590163933
# Four By Two Productions : 12.0

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
title=data['original_title']
title_list=[]
for i in title:
    s=[]
    s=i.lower().split()
    for j in s:
        title_list.append(j)
title_list
# Out:
# ['jurassic',
#  'world',
#  'mad',
#  'max:',
#  'fury',
#  'road',
#  'insurgent',
#  'star',
#  'wars:',
#  'the',
#  'force',
#  'awakens',
#  'furious',
#  '7',
#  'the',
#  'revenant',
#  'terminator',
#  'genisys',
#  'the',
#  'martian',
#  'minions',
#  'inside',
#  'out',
#  'spectre',
#  'jupiter',
#  'ascending',
#  'ex',
#  'machina',
#  'pixels',
#  'avengers:',
#  'age',
#  'of',
#  'ultron',
#  'the',
#  'hateful',
#  'eight',
#  'taken',
#  '3',
#  'ant-man',
#  'cinderella',
#  'the',
#  'hunger',
#  'games:',
#  'mockingjay',
#  '-',
#  'part',
#  '2',
#  'tomorrowland',
#  'southpaw',
#  'san',
#  'andreas',
#  'fifty',
#  'shades',
#  'of',
#  'grey',
#  'the',
#  'big',
#  'short',
#  'mission:',
#  'impossible',
#  '-',
#  'rogue',
#  'nation',
#  'ted',
#  '2',
#  'kingsman:',
#  'the',
#  'secret',
#  'service',
#  'spotlight',
#  'maze',
#  'runner:',
#  'the',
#  'scorch',
#  'trials',
#  'chappie',
#  'pitch',
#  'perfect',
#  '2',
#  'bridge',
#  'of',
# ...

# %%
pd.Series(title_list).nunique()
# Out:
# 2461

# %%
answer_ls.append(3)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data.shape
# Out:
# (1890, 20)

# %%
data.sort_values(by='vote_average',ascending=False).head(19)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 600   tt0468569    8.466668  185000000  1001921825
# 125   tt2084970    8.110711   14000000   233555708
# 9     tt2096673    6.326804  175000000   853708609
# 118   tt0816692   24.949134  165000000   621752480
# 34    tt3170832    3.557846    6000000    35401758
# 1082  tt0167260    7.122455   94000000  1118888979
# 873   tt0253474    2.364204   35000000   120072577
# 1801  tt0209144    3.095625    9000000    39723096
# 1192  tt2024544    3.625529   20000000   187000000
# 128   tt2267998    6.438727   61000000   369330363
# 138   tt2278388    4.930820   30000000   174600318
# 119   tt2015381   14.311205  170000000   773312399
# 1184  tt0993846    4.877927  100000000   392000694
# 370   tt1375666    9.363643  160000000   825500000
# 316   tt1187043    0.816681    9000000    70000000
# 1564  tt0338013    3.863377   20000000    72258126
# 497   tt0120737    8.575419   93000000   871368364
# ...

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
acter=[['Johnny Depp','Helena Bonham Carter'],['Hugh Jackman','Ian McKellen'],['Vin Diesel','Paul Walker'],['Adam Sandler','Kevin James'],['Daniel Radcliffe','Rupert Grint']]
for x in acter:
    xx=data[(data.cast.str.contains(x[0]))&(data.cast.str.contains(x[1]))].cast.count()
    print(x[0],'&',x[1],':',xx)
# Out:
# Johnny Depp & Helena Bonham Carter : 6
# Hugh Jackman & Ian McKellen : 5
# Vin Diesel & Paul Walker : 5
# Adam Sandler & Kevin James : 5
# Daniel Radcliffe & Rupert Grint : 8

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
director1=['Quentin Tarantino', 'Steven Soderbergh','Robert Rodriguez','Christopher Nolan','Clint Eastwood']
for i in director1:
    x=data[(data.director.str.contains(i))&(data.profit>0)].director.count()/data[data.director.str.contains(i)].director.count()
    print(i,':',x)
# Out:
# Quentin Tarantino : 0.8571428571428571
# Steven Soderbergh : 0.7692307692307693
# Robert Rodriguez : 0.7272727272727273
# Christopher Nolan : 1.0
# Clint Eastwood : 0.8333333333333334

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
